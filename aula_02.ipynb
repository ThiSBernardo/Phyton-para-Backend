# %%
class Leitura:
    
    def __init__(self, nome: str):
        self.nome = nome
        self.abacate = False
        self.abacaxi = False

    def __enter__(self):
        print(self)
        return self

    def __exit__(self, a, b, c):
        print('saiu', a, b, c)

    def __repr__(self):
        return f'Leitura({self.nome})'

# %%
with Leitura('arquivo.txt') as l:
    1.abacate = True
    print(l.abacate)
# Out:
#   Cell In[47], line 2
#     1.abacate = True
#       ^
# SyntaxError: invalid syntax
